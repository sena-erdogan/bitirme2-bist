# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings("ignore")

# %%
filename = "PP_GUNSONUFIYATHACIM.M."
year = "2023"
month = "01"
filename = filename + year + month + ".csv"
filename
# Out:
# 'PP_GUNSONUFIYATHACIM.M.202301.csv'

# %%
data = pd.read_csv(filename, sep=';')

# %%
data
# Out:
#             TARIH             ISLEM  KODU
# 0      TRADE DATE  INSTRUMENT SERIES CODE  \
# 1      2022-11-08                 ABIAP.V
# 2      2022-11-22                 ABIAP.V
# 3      2022-11-18                 ABIAP.V
# 4      2022-11-21                 ABIAP.V
# ...           ...                     ...
# 60575  2022-11-11                 ZTM15.F
# 60576  2022-11-01                 ZTM15.F
# 60577  2022-11-02                 ZTM15.F
# 60578  2022-11-03                 ZTM15.F
# 60579  2022-11-28                 ZTM15.F
#
#                                            BULTEN ADI         PAZAR GRUBU
# 0                                     INSTRUMENT NAME  MARKET SUB SEGMENT  \
# 1                     AKBNKC3012220015.60IYM0000001NA                 NaN
# 2                     AKBNKC3012220015.60IYM0000001NA                 NaN
# 3                     AKBNKC3012220015.60IYM0000001NA                 NaN
# 4                     AKBNKC3012220015.60IYM0000001NA                 NaN
# ...

# %%
data.shape
# Out:
# (60580, 52)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60580 entries, 0 to 60579
# Data columns (total 52 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   TARIH                                        60580 non-null  object
#  1   ISLEM  KODU                                  60580 non-null  object
#  2   BULTEN ADI                                   60580 non-null  object
#  3   PAZAR GRUBU                                  1 non-null      object
#  4   PAZAR                                        60580 non-null  object
#  5   YAPISAL BAZDA PIYASA ALT BOLUMU              60580 non-null  object
#  6   ENSTRUMAN GRUBU                              60580 non-null  object
#  7   ENSTRUMAN TIPI                               60580 non-null  object
#  8   ENSTRUMAN SINIFI                             60580 non-null  object
# ...

# %%
del data['BULTEN ADI']
del data['PAZAR GRUBU']
del data['PAZAR']
del data['YAPISAL BAZDA PIYASA ALT BOLUMU']
del data['ENSTRUMAN GRUBU']
del data['ENSTRUMAN TIPI']
del data['ENSTRUMAN SINIFI']
del data['ISLEM YONTEMI']
del data['PIYASA YAPICI']
del data['BIST 100 ENDEKS']
del data['BIST 30 ENDEKS']
del data['BRUT TAKAS']
del data['OZSERMAYE HALI']
del data['GECICI DURDURMA']
del data['A.O.F']
del data['TOPLAM ISLEM HACMI']
del data['TOPLAM ISLEM ADEDI']
del data['TOPLAM SOZLESME SAYISI']
del data['REFERANS FIYAT']
del data['ACILIS SEANSI ISLEM HACMI']
del data['ACILIS SEANSI ISLEM MIKTARI']
del data['ACILIS SEANSI SOZLESME SAYISI']
del data['KAPANIS SEANSI ISLEM HACMI']
del data['KAPANIS SEANSI ISLEM MIKTARI']
del data['KAPANIS SEANSI SOZLESME SAYISI']
del data['KAPANIS FIYATINDAN ISLEMLER ISLEM HACMI']
del data['KAPANIS FIYATINDAN ISLEMLER ISLEM MIKTARI']
del data['KAPANIS FIYATINDAN ISLEMLER SOZLESME SAYISI']
del data['ACIGA SATIS A.O.F']
del data['ACIGA SATIS ISLEM HACMI']
del data['ACIGA SATIS ISLEM ADEDI']
del data['ACIGA SATIS SOZLESME SAYISI']
del data['OZEL ISLEM BILDIRIMI EN DUSUK FIYAT']
del data['OZEL ISLEM BILDIRIMI EN YUKSEK FIYAT']
del data['OZEL ISLEM BILDIRIMI A.O.F.']
del data['OZEL ISLEM BILDIRIMI ISLEM HACMI']
del data['OZEL ISLEM BILDIRIMI ISLEM ADEDI']
del data['OZEL ISLEM BILDIRIMI SOZLESME SAYISI']
del data['ACILIS SEANSI FIYATI']
del data['KAPANIS SEANSI FIYATI']
del data['EN DUSUK ACIGA SATIS FIYATI']
del data['EN YUKSEK ACIGA SATIS FIYATI']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60041 entries, 0 to 60040
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   TARIH                  60041 non-null  object
#  1   ISLEM  KODU            60041 non-null  object
#  2   ONCEKI KAPANIS FIYATI  59152 non-null  object
#  3   ACILIS FIYATI          60041 non-null  object
#  4   EN DUSUK FIYAT         60041 non-null  object
#  5   EN YUKSEK FIYAT        60041 non-null  object
#  6   KAPANIS FIYATI         60041 non-null  object
#  7   DEGISIM (%)            60041 non-null  object
#  8   BEKLEYEN EN IYI ALIS   60041 non-null  object
#  9   BEKLEYEN EN IYI SATIS  60041 non-null  object
# dtypes: object(10)
# memory usage: 4.6+ MB

# %%
data
# Out:
#             TARIH             ISLEM  KODU ONCEKI KAPANIS FIYATI
# 0      TRADE DATE  INSTRUMENT SERIES CODE   PREVIOUS LAST PRICE  \
# 1      2023-01-20                 ABIAU.V                   2.3
# 2      2023-01-18                 ABIAU.V                  2.18
# 3      2023-01-16                 ABIAU.V                  1.55
# 4      2023-01-13                 ABIAU.V                  1.74
# ...           ...                     ...                   ...
# 60036  2023-01-02                 ZTM15.F                 60.28
# 60037  2023-01-03                 ZTM15.F                 62.26
# 60038  2023-01-04                 ZTM15.F                 62.62
# 60039  2023-01-05                 ZTM15.F                  61.6
# 60040  2023-01-30                 ZTM15.F                 56.92
#
#        ACILIS FIYATI EN DUSUK FIYAT EN YUKSEK FIYAT KAPANIS FIYATI
# 0      OPENING PRICE   LOWEST PRICE   HIGHEST PRICE  CLOSING PRICE  \
# ...
