# %%
import os
import tweepy as tw
import pandas as pd
import apikey
 
#gerekli
consumer_key = "FLcLHFJh7UCOwjSGt81SooD8R"
consumer_secret = "58R8WsVkgWbjiBJpgpvdV3qEQcDzwpRdk1VbxFmTlIaThzkgHd"
access_token = "784007209005047808-id46WpJU3rJsf7pgASjObgj17ZuDEO5"
access_token_secret = "Yi8ZHCyrwqBhvjfu3vyvnJpRUrnYVoOOkmpONQXgJgrym"
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

#data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

#display(data.head(10))


for tweet in tw.Cursor(api.search_tweets, q='deprem', lang='tr').items(10):
    print(f"{tweet.user.name} said: {tweet.text}")
# Out:
# ---------------------------------------------------------------------------
# Forbidden                                 Traceback (most recent call last)
# Cell In[10], line 19
#      12 api = tw.API(auth, wait_on_rate_limit=True)
#      14 #data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])
#      15
#      16 #display(data.head(10))
# ---> 19 for tweet in tw.Cursor(api.search_tweets, q='deprem', lang='tr').items(10):
#      20     print(f"{tweet.user.name} said: {tweet.text}")
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tweepy\cursor.py:86, in BaseIterator.__next__(self)
#      85 def __next__(self):
# ---> 86     return self.next()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\tweepy\cursor.py:286, in ItemIterator.next(self)
#     283     raise StopIteration
#     284 if self.current_page is None or self.page_index == len(self.current_page) - 1:
# ...

# %%
# importing libraries and packages
import snscrape.modules.twitter as sntwitter
import pandas

# Creating list to append tweet data 
tweets_list = []

# Using TwitterSearchScraper to scrape data and append tweets to list
for i,tweet in enumerate(sntwitter.TwitterSearchScraper('from:aslanamca1983').get_items()): #declare a username 
    if i>1000: #number of tweets you want to scrape
        break
    tweets_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username]) #declare the attributes to be returned
    
# Creating a dataframe from the tweets list above 
tweets_df = pd.DataFrame(tweets_list, columns=['Datetime', 'Tweet Id', 'Text', 'Username'])
tweets_df.to_csv("aslanamca1983-tweets.csv", index = False)
# Out:
# C:\Users\senae\AppData\Local\Temp\ipykernel_10848\1110963834.py:12: DeprecatedFeatureWarning: content is deprecated, use rawContent instead
#   tweets_list.append([tweet.date, tweet.id, tweet.content, tweet.user.username]) #declare the attributes to be returned

# %%
tweets_df
# Out:
#                      Datetime             Tweet Id
# 0   2023-04-18 16:06:57+00:00  1648357457482137605  \
# 1   2023-04-18 15:37:19+00:00  1648349999309225985
# 2   2023-04-18 15:03:56+00:00  1648341599762501633
# 3   2023-04-18 14:57:39+00:00  1648340018765725697
# 4   2023-04-18 13:49:02+00:00  1648322747938766848
# ..                        ...                  ...
# 553 2023-03-13 06:42:19+00:00  1635169400247685125
# 554 2023-03-12 20:00:57+00:00  1635007993501847552
# 555 2023-03-12 14:09:45+00:00  1634919611882930176
# 556 2023-03-12 11:27:25+00:00  1634878758141173760
# 557 2023-03-12 09:08:31+00:00  1634843802916769794
#
#                                                   Text       Username
# 0    Bana her gün böyle bir mesaj geliyor. Şahsıma ...  aslanamca1983
# 1    Şuraya bir bakın. PEGASUS son dakika siz çevir...  aslanamca1983
# 2    PEGASUS dün kapanışta verdiğim PETKİM ve TÜPRA...  aslanamca1983
# ...

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

# Define the search parameters
query = 'coronavirus'
language = 'tr'
since_date = '2010-01-01'
until_date = '2024-12-31'

# Use snscrape to scrape the data
url = f'https://eksisozluk.com/{query}--{language}?a=daterange:{since_date},{until_date}'
tweets = list(sntwitter.TwitterSearchScraper(url).get_items())

# Process the scraped data
results = []
for tweet in tweets:
    text = tweet.content
    date = tweet.date.strftime('%Y-%m-%d %H:%M:%S')
    results.append({'text': text, 'date': date})

# Create a pandas dataframe to store the results
df = pd.DataFrame(results)

# Print the dataframe
print(df)
# Out:
# Error retrieving https://api.twitter.com/2/search/adaptive.json?include_profile_interstitial_type=1&include_blocking=1&include_blocked_by=1&include_followed_by=1&include_want_retweets=1&include_mute_edge=1&include_can_dm=1&include_can_media_tag=1&include_ext_has_nft_avatar=1&include_ext_is_blue_verified=1&include_ext_verified_type=1&skip_status=1&cards_platform=Web-12&include_cards=1&include_ext_alt_text=true&include_ext_limited_action_results=false&include_quote_count=true&include_reply_count=1&tweet_mode=extended&include_ext_collab_control=true&include_ext_views=true&include_entities=true&include_user_entities=true&include_ext_media_color=true&include_ext_media_availability=true&include_ext_sensitive_media_warning=true&include_ext_trusted_friends_metadata=true&send_error_codes=true&simple_quoted_tweet=true&q=https%3A%2F%2Feksisozluk.com%2Fcoronavirus--tr%3Fa%3Ddaterange%3A2010-01-01%2C2024-12-31&tweet_search_mode=live&count=20&query_source=spelling_expansion_revert_click&pc=1&spell
# ...

# %%
import pandas as pd
from tqdm.notebook import tqdm
import snscrape.modules.twitter as sntwitter

scraper = sntwitter.TwitterSearchScraper("deprem")

for tweet in scraper.get_items():
    break

tweet

scraper = sntwitter.TwitterSearchScraper("deprem")

tweets = []

for i, tweet in enumerate(scraper.get_items()):
    data = [
        tweet.date, tweet.id, tweet.content, tweet.user.username, tweet.likeCount, tweet.retweetCount
    ]
    tweets.append(data)
    if i > 50:
        break

tweet_df = pd.DataFrame(
    tweets, columns = [
        "date", "id", "content", "username", "likeCount", "retweetCount"
    ]
)

tweet_df.to_csv("deprem-tweets.csv", index = False)
